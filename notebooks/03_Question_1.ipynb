# %%
import pandas as pd
import numpy as np

# %%
cols = [
    # Adresse
    "adresse_ban",

    # Structure logement & immeuble 
    "type_batiment",
    "annee_construction",
    "periode_construction",
    "nombre_appartement",
    "surface_habitable_desservie_par_installation_ecs_n1",
    "surface_chauffee_installation_chauffage_n1",
    "surface_chauffee_installation_chauffage_n2",
    "surface_climatisee",

    # DPE
    "etiquette_dpe",
    "etiquette_ges",
    "date_etablissement_dpe",
    "date_derniere_modification_dpe",

    # Chauffage électrique
    "conso_chauffage_ef_energie_n1",
    "conso_chauffage_ef_energie_n2",
    "conso_chauffage_ef_energie_n3",
    "conso_chauffage_ep",
    "type_energie_n1",
    "type_energie_n2",
    "type_energie_n3",

    # ECS électrique
    "conso_ecs_ef_energie_n1",
    "conso_ecs_ef_energie_n2",
    "conso_ecs_ef_energie_n3",

    # Éclairage
    "conso_eclairage_ef",

    # Auxiliaires
    "conso_auxiliaires_ef",

    # Refroidissement
    "conso_refroidissement_ef",

    # Coût 
    "cout_chauffage_energie_n1",
    "cout_chauffage_energie_n2",
    "cout_chauffage_energie_n3",
    "cout_ecs_energie_n1",
    "cout_ecs_energie_n2",
    "cout_ecs_energie_n3",
    "cout_eclairage",
    "cout_auxiliaires",
    "cout_refroidissement"
]

# %%
df_dpe_75 = pd.read_csv("../data/dpe/dpe_paris_full.csv", usecols=cols, low_memory=False)
df_dpe_75.head()
# Out:
#    cout_eclairage  conso_auxiliaires_ef date_etablissement_dpe  \
# 0            17.6                 405.2             2022-02-07
# 1            21.0                  14.0             2022-06-06
# 2            71.8                 202.0             2022-03-09
# 3            24.1                 262.0             2022-05-31
# 4           100.3                 575.1             2022-06-23
#
#    conso_ecs_ef_energie_n1  conso_ecs_ef_energie_n2  cout_ecs_energie_n2  \
# 0                   3670.8                      0.0                  0.0
# 1                   1631.8                      0.0                  0.0
# 2                   3957.6                      0.0                  0.0
# 3                   1575.0                      0.0                  0.0
# 4                   2858.8                      0.0                  0.0
#
#    conso_chauffage_ef_energie_n1  conso_chauffage_ef_energie_n2  \
# 0                         3506.6                            0.0
# ...

# %%
df_dpe_75["conso_chauffage_elec"] = (
    np.where(df_dpe_75["type_energie_n1"] == "Électricité", df_dpe_75["conso_chauffage_ef_energie_n1"], 0) +
    np.where(df_dpe_75["type_energie_n2"] == "Électricité", df_dpe_75["conso_chauffage_ef_energie_n2"], 0) +
    np.where(df_dpe_75["type_energie_n3"] == "Électricité", df_dpe_75["conso_chauffage_ef_energie_n3"], 0)
)

# %%
df_dpe_75["conso_ecs_elec"] = (
    np.where(df_dpe_75["type_energie_n1"] == "Électricité", df_dpe_75["conso_ecs_ef_energie_n1"], 0) +
    np.where(df_dpe_75["type_energie_n2"] == "Électricité", df_dpe_75["conso_ecs_ef_energie_n2"], 0) +
    np.where(df_dpe_75["type_energie_n3"] == "Électricité", df_dpe_75["conso_ecs_ef_energie_n3"], 0)
)

# %%
df_dpe_75["conso_eclairage_elec"] = df_dpe_75["conso_eclairage_ef"].fillna(0)
df_dpe_75["conso_auxiliaires_elec"] = df_dpe_75["conso_auxiliaires_ef"].fillna(0)
df_dpe_75["conso_refroidissement_elec"] = df_dpe_75["conso_refroidissement_ef"].fillna(0)

# %%
df_dpe_75["totale_conso_electrique"] = (
    df_dpe_75["conso_chauffage_elec"] +
    df_dpe_75["conso_ecs_elec"] +
    df_dpe_75["conso_eclairage_elec"] +
    df_dpe_75["conso_auxiliaires_elec"] +
    df_dpe_75["conso_refroidissement_elec"]
)

# %%
df_dpe_75["cout_chauffage_elec"] = (
    np.where(df_dpe_75["type_energie_n1"] == "Électricité", df_dpe_75["cout_chauffage_energie_n1"], 0) +
    np.where(df_dpe_75["type_energie_n2"] == "Électricité", df_dpe_75["cout_chauffage_energie_n2"], 0) +
    np.where(df_dpe_75["type_energie_n3"] == "Électricité", df_dpe_75["cout_chauffage_energie_n3"], 0)
)

# %%
df_dpe_75["cout_ecs_elec"] = (
    np.where(df_dpe_75["type_energie_n1"] == "Électricité", df_dpe_75["cout_ecs_energie_n1"], 0) +
    np.where(df_dpe_75["type_energie_n2"] == "Électricité", df_dpe_75["cout_ecs_energie_n2"], 0) +
    np.where(df_dpe_75["type_energie_n3"] == "Électricité", df_dpe_75["cout_ecs_energie_n3"], 0)
)

# %%
df_dpe_75["cout_eclairage_elec"] = df_dpe_75["cout_eclairage"].fillna(0)
df_dpe_75["cout_auxiliaires_elec"] = df_dpe_75["cout_auxiliaires"].fillna(0)
df_dpe_75["cout_refroidissement_elec"] = df_dpe_75["cout_refroidissement"].fillna(0)

# %%
df_dpe_75["totale_cout_electrique"] = (
    df_dpe_75["cout_chauffage_elec"]
    + df_dpe_75["cout_ecs_elec"]
    + df_dpe_75["cout_eclairage_elec"]
    + df_dpe_75["cout_auxiliaires_elec"]
    + df_dpe_75["cout_refroidissement_elec"]
)

# %%
df_dpe_75["periode_construction"].unique()
# Out:
# array(['1948-1974', 'avant 1948', '1989-2000', '1975-1977', '2013-2021',
#        '2006-2012', '1983-1988', '1978-1982', 'après 2021', '2001-2005'],
#       dtype=object)

# %%
df_test = df_dpe_75[df_dpe_75["adresse_ban"] == "32 Rue Ginoux 75015 Paris"].head()

# %%
df_test["periode_construction"]
# Out:
# 170768    1948-1974
# 177586    1948-1974
# 311718    1948-1974
# 470651    1948-1974
# 595765    1948-1974
# Name: periode_construction, dtype: object

# %%
#df_dpe_75["adresse_ban"].value_counts()[lambda x: x > 1]

# %%
#df_dpe_75[df_dpe_75["adresse_ban"] == "32 Rue Ginoux 75015 Paris"]

# %%
#len(df_dpe_75[df_dpe_75["etiquette_dpe"] == "A"])

# %%
#df_conso_75 = pd.read_csv("../data/edenis/consommation-annuelle-residentielle-par-adresse-Paris.csv", low_memory=False)
#df_conso_75.head()

# %%
df_dpe_filtre = df_dpe_75[["etiquette_dpe", "totale_conso_electrique", "totale_cout_electrique"]]
df_dpe_filtre.head()
# Out:
#   etiquette_dpe  totale_conso_electrique  totale_cout_electrique
# 0             D                    465.7                   112.6
# 1             D                     86.9                   837.0
# 2             D                    449.6                   130.4
# 3             C                    655.7                   140.4
# 4             E                    920.8                   267.1

# %%
somme_A_conso = df_dpe_filtre.loc[df_dpe_filtre["etiquette_dpe"] == "A", "totale_conso_electrique"].sum()
somme_A_cout = df_dpe_filtre.loc[df_dpe_filtre["etiquette_dpe"] == "A", "totale_cout_electrique"].sum()
print("Total comsomation:")
print(somme_A_conso)
print("Total coût:")
print(somme_A_cout)
# Out:
# Total comsomation:
# 343365.20000000007
# Total coût:
# 73227.8

# %%
somme_B_conso = df_dpe_filtre.loc[df_dpe_filtre["etiquette_dpe"] == "B", "totale_conso_electrique"].sum()
somme_B_cout = df_dpe_filtre.loc[df_dpe_filtre["etiquette_dpe"] == "B", "totale_cout_electrique"].sum()
print("Total comsomation:")
print(somme_B_conso)
print("Total coût:")
print(somme_B_cout)
# Out:
# Total comsomation:
# 11838229.5
# Total coût:
# 2755499.0

# %%
somme_C_conso = df_dpe_filtre.loc[df_dpe_filtre["etiquette_dpe"] == "C", "totale_conso_electrique"].sum()
somme_C_cout = df_dpe_filtre.loc[df_dpe_filtre["etiquette_dpe"] == "C", "totale_cout_electrique"].sum()
print("Total comsomation:")
print(somme_C_conso)
print("Total coût:")
print(somme_C_cout)
# Out:
# Total comsomation:
# 284715330.40000004
# Total coût:
# 66854169.3

# %%
somme_D_conso = df_dpe_filtre.loc[df_dpe_filtre["etiquette_dpe"] == "D", "totale_conso_electrique"].sum()
somme_D_cout = df_dpe_filtre.loc[df_dpe_filtre["etiquette_dpe"] == "D", "totale_cout_electrique"].sum()
print("Total comsomation:")
print(somme_D_conso)
print("Total coût:")
print(somme_D_cout)
# Out:
# Total comsomation:
# 777483023.0999999
# Total coût:
# 169032238.3

# %%
somme_E_conso = df_dpe_filtre.loc[df_dpe_filtre["etiquette_dpe"] == "E", "totale_conso_electrique"].sum()
somme_E_cout = df_dpe_filtre.loc[df_dpe_filtre["etiquette_dpe"] == "E", "totale_cout_electrique"].sum()
print("Total comsomation:")
print(somme_E_conso)
print("Total coût:")
print(somme_E_cout)
# Out:
# Total comsomation:
# 789136648.5999999
# Total coût:
# 168363188.70000002

# %%
somme_F_conso = df_dpe_filtre.loc[df_dpe_filtre["etiquette_dpe"] == "F", "totale_conso_electrique"].sum()
somme_F_cout = df_dpe_filtre.loc[df_dpe_filtre["etiquette_dpe"] == "F", "totale_cout_electrique"].sum()
print("Total comsomation:")
print(somme_F_conso)
print("Total coût:")
print(somme_F_cout)
# Out:
# Total comsomation:
# 582459341.0999999
# Total coût:
# 118337827.89999999

# %%
somme_G_conso = df_dpe_filtre.loc[df_dpe_filtre["etiquette_dpe"] == "G", "totale_conso_electrique"].sum()
somme_G_cout = df_dpe_filtre.loc[df_dpe_filtre["etiquette_dpe"] == "G", "totale_cout_electrique"].sum()
print("Total comsomation:")
print(somme_G_conso)
print("Total coût:")
print(somme_G_cout)
# Out:
# Total comsomation:
# 670300178.0
# Total coût:
# 130114105.7

# %%
somme_A_conso = df_dpe_filtre.loc[df_dpe_filtre["etiquette_dpe"] == "A", "totale_conso_electrique"].sum()
somme_A_cout = df_dpe_filtre.loc[df_dpe_filtre["etiquette_dpe"] == "A", "totale_cout_electrique"].sum()
print("Total comsomation:")
print(somme_A_conso)
print("Total coût:")
print(somme_A_cout)
