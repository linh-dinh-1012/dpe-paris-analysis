# %%
import pandas as pd

# %%
df_ban_75 = pd.read_csv("../data/BAN/adresses-75.csv", sep=";")
df_ban_75.head()
# Out:
#                    id id_fantoir  numero  rep                     nom_voie  \
# 0  75101_cfq3tf_00001        NaN       1  NaN  Avenue du Général Lemonnier
# 1  75101_cfq3tf_00002        NaN       2  NaN  Avenue du Général Lemonnier
# 2  75101_cfq3tf_00003        NaN       3  NaN  Avenue du Général Lemonnier
# 3  75101_cfq3tf_00004        NaN       4  NaN  Avenue du Général Lemonnier
# 4  75101_cfq3tf_00005        NaN       5  NaN  Avenue du Général Lemonnier
#
#    code_postal  code_insee               nom_commune  \
# 0        75001       75101  Paris 1er Arrondissement
# 1        75001       75101  Paris 1er Arrondissement
# 2        75001       75101  Paris 1er Arrondissement
# 3        75001       75101  Paris 1er Arrondissement
# 4        75001       75101  Paris 1er Arrondissement
#
#    code_insee_ancienne_commune  nom_ancienne_commune  ...        lat  \
# 0                          NaN                   NaN  ...  48.861299
# ...

# %%
df_ban_75.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152331 entries, 0 to 152330
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           152331 non-null  object
#  1   id_fantoir                   150637 non-null  object
#  2   numero                       152331 non-null  int64
#  3   rep                          13878 non-null   object
#  4   nom_voie                     152331 non-null  object
#  5   code_postal                  152331 non-null  int64
#  6   code_insee                   152331 non-null  int64
#  7   nom_commune                  152331 non-null  object
#  8   code_insee_ancienne_commune  0 non-null       float64
#  9   nom_ancienne_commune         0 non-null       float64
#  10  x                            152331 non-null  float64
#  11  y                            152331 non-null  float64
# ...

# %%
df_conso = pd.read_csv("../data/edenis/consommation-annuelle-residentielle-par-adresse.csv", sep=";", low_memory=False)
df_conso.head()
# Out:
#    Année  Code IRIS  Nom IRIS  Numéro de voie Indice de répétition  \
# 0   2018  920040601  Renoir i             8.0                  NaN
# 1   2018  920040601  Renoir i             7.0                  NaN
# 2   2018  920040601  Renoir i             6.0                  NaN
# 3   2018  920040604     Metro           184.0                  NaN
# 4   2018  920040604     Metro           154.0                  NaN
#
#   Type de voie Libellé de voie  Code Commune         Nom Commune  \
# 0        ALLEE        VISCONTI         92004  ASNIERES-SUR-SEINE
# 1        ALLEE        VISCONTI         92004  ASNIERES-SUR-SEINE
# 2        ALLEE        VISCONTI         92004  ASNIERES-SUR-SEINE
# 3    BOULEVARD        VOLTAIRE         92004  ASNIERES-SUR-SEINE
# 4    BOULEVARD        VOLTAIRE         92004  ASNIERES-SUR-SEINE
#
#   Segment de client  Nombre de logements  \
# 0       RESIDENTIEL                   10
# 1       RESIDENTIEL                   10
# ...

# %%
df_conso_paris = df_conso[df_conso["Nom Commune"].str.upper() == "PARIS"]

# %%
df_conso_paris
# Out:
#          Année  Code IRIS           Nom IRIS  Numéro de voie  \
# 25545     2019  751187206         Chapelle 6             2.0
# 25546     2019  751207802    Saint-Fargeau 2             2.0
# 25547     2019  751051903     Val de Grace 3            44.0
# 25548     2019  751051903     Val de Grace 3            42.0
# 25549     2019  751051903     Val de Grace 3            41.0
# ...        ...        ...                ...             ...
# 2767075   2021  751207813   Saint-Fargeau 13            20.0
# 2767076   2021  751031002   Enfants Rouges 2             7.0
# 2767077   2021  751114106  Folie Méricourt 6            36.0
# 2767078   2021  751114106  Folie Méricourt 6            12.0
# 2767079   2021  751041301      Saint-Merri 1            56.0
#
#         Indice de répétition Type de voie   Libellé de voie  Code Commune  \
# 25545                    NaN        PLACE  PIERRE MAC ORLAN         75056
# 25546                    NaN          RUE  PIERRE MOUILLARD         75056
# ...

# %%
df_conso_paris.to_csv("../data/edenis/consommation-annuelle-residentielle-par-adresse-Paris.csv", index=False, encoding='utf-8')

# %%
df_conso.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2821929 entries, 0 to 2821928
# Data columns (total 19 columns):
#  #   Column                                                         Non-Null Count    Dtype
# ---  ------                                                         --------------    -----
#  0   Année                                                          2821929 non-null  int64
#  1   Code IRIS                                                      2821929 non-null  object
#  2   Nom IRIS                                                       2821929 non-null  object
#  3   Numéro de voie                                                 2821922 non-null  float64
#  4   Indice de répétition                                           154203 non-null   object
#  5   Type de voie                                                   2810900 non-null  object
#  6   Libellé de voie                                                2821929 non-null  object
# ...

# %%
df_dpe_75 = pd.read_csv("../data/dpe/dpe_paris_full.csv", nrows=5000, low_memory=False)
df_dpe_75.head(10)
# Out:
#   configuration_installation_chauffage_n1  \
# 0        Installation de chauffage simple
# 1        Installation de chauffage simple
# 2        Installation de chauffage simple
# 3        Installation de chauffage simple
# 4        Installation de chauffage simple
# 5        Installation de chauffage simple
# 6        Installation de chauffage simple
# 7        Installation de chauffage simple
# 8        Installation de chauffage simple
# 9        Installation de chauffage simple
#
#    conso_chauffage_installation_chauffage_n1  \
# 0                                     3506.6
# 1                                     6044.4
# 2                                    17567.8
# 3                                     3838.1
# 4                                    40734.6
# 5                                     1440.5
# 6                                     2514.8
# 7                                     2814.2
# 8                                     3754.3
# ...

# %%
df_dpe_75.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Columns: 225 entries, configuration_installation_chauffage_n1 to numero_rpls_logement
# dtypes: float64(127), int64(8), object(90)
# memory usage: 8.6+ MB

# %%
df_dpe_75.shape
# Out:
# (5000, 225)

# %%
list(df_dpe_75.columns)
# Out:
# ['configuration_installation_chauffage_n1',
#  'conso_chauffage_installation_chauffage_n1',
#  'type_generateur_n1_ecs_n1',
#  'numero_voie_ban',
#  'score_ban',
#  'surface_habitable_immeuble',
#  'conso_auxiliaires_ep',
#  'deperditions_murs',
#  'cout_eclairage',
#  'conso_auxiliaires_ef',
#  'statut_geocodage',
#  'ventilation_posterieure_2012',
#  'cout_chauffage',
#  'conso_5_usages_par_m2_ep',
#  'date_etablissement_dpe',
#  'conso_ecs_ef_energie_n1',
#  'conso_ecs_ef_energie_n2',
#  'emission_ges_chauffage',
#  'description_installation_chauffage_n1',
#  'conso_5_usages_par_m2_ef',
#  'cout_ecs_energie_n2',
#  'conso_chauffage_ef_energie_n1',
#  'conso_chauffage_ef_energie_n2',
#  'qualite_isolation_menuiseries',
#  'cout_total_5_usages_energie_n2',
#  'date_reception_dpe',
#  'cout_total_5_usages_energie_n1',
#  'cout_ecs_energie_n1',
#  'qualite_isolation_plancher_bas',
#  'modele_dpe',
#  'qualite_isolation_enveloppe',
#  'conso_chauffage_generateur_n1_installation_n1',
# ...
